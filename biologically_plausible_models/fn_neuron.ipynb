# %% [markdown]
# # FitzHugh-Nagumo Model

# %%
import numpy as np
from matplotlib import pyplot

# %%
w = -0.625
v = -1.2

input_current = np.zeros(250)
input_current[0:49] = 0.3

# %%
for I in input_current:
    dv = v - (v**3 / 3) - w  + I
    dw = 0.08 * v - 0.064 * w + 0.056
# Out:
#   Cell In[3], line 3
#
#     ^
# _IncompleteInputError: incomplete input
